# %%
from datetime import datetime
import matplotlib.pyplot as plt
from meteostat import Point, Daily
import pandas as pd
pd.set_option("display.max_rows", None, "display.max_columns", None)

# %matplotlib inline

# %%
start = datetime(2020, 6, 1)
end = datetime(2023, 6, 30)
location = Point(46.74450299013103, -92.1901095496724)

# %%
data = Daily(location, start, end)
data = data.fetch()

# %%
data
# Out:
#             tavg  tmin  tmax  prcp   snow   wdir  wspd  wpgt    pres  tsun
# time
# 2020-06-01  11.1   6.7  14.0   0.3    0.0   33.0   6.0   NaN  1012.3   NaN
# 2020-06-02  19.6   8.7  30.3   0.0    0.0  283.0   7.4   NaN  1008.9   NaN
# 2020-06-03  19.4  12.2  26.3   0.0    0.0  291.0  10.0   NaN  1009.7   NaN
# 2020-06-04  17.9   7.2  28.2   0.5    0.0  281.0   9.2   NaN  1007.7   NaN
# 2020-06-05  19.9  13.5  25.7   0.5    0.0  287.0  15.9   NaN  1011.6   NaN
# 2020-06-06  11.1   6.1  16.1   0.0    0.0   40.0  11.1   NaN  1020.6   NaN
# 2020-06-07   7.6   6.0  11.2   4.3    0.0   61.0  22.1   NaN  1015.7   NaN
# 2020-06-08  10.3   6.0  14.8   0.0    0.0   49.0  11.2   NaN  1008.7   NaN
# 2020-06-09  10.0   7.8  13.1   0.8    0.0   42.0   9.3   NaN  1004.3   NaN
# 2020-06-10  15.4   9.7  20.2   0.3    0.0  297.0  20.8   NaN  1000.6   NaN
# 2020-06-11  15.5  10.1  22.3   0.3    0.0  270.0  15.1   NaN  1014.0   NaN
# ...

# %%
data.plot(y=['prcp'])
plt.show()

# %%
from meteostat import Stations

# Get nearby weather stations
stations = Stations()
stations = stations.nearby(46.74450299013103, -92.1901095496724)
station = stations.fetch(5)

print (station)
# Out:
#                                name country region    wmo  icao  latitude  \
# id
# KSUW0     Superior / South Superior      US     WI   <NA>  KSUW   46.6897
# 72745  Duluth International Airport      US     MN  72745  KDLH   46.8333
# KDYT0             Duluth / East End      US     MN   <NA>  KDYT   46.7219
# KCOQ0                       Cloquet      US     MN   <NA>  KCOQ   46.7011
# KTWM0           Two Harbors / Waldo      US     MN   <NA>  KTWM   47.0491
#
#        longitude  elevation         timezone hourly_start hourly_end  \
# id
# KSUW0   -92.0947      205.0  America/Chicago   2006-01-01 2023-08-09
# 72745   -92.2167      435.0  America/Chicago   1948-01-01 2023-08-09
# KDYT0   -92.0434      186.0  America/Chicago   2006-01-01 2023-08-02
# KCOQ0   -92.5036      390.0  America/Chicago   2006-01-01 2023-08-09
# KTWM0   -91.7452      327.0  America/Chicago   2006-01-01 2023-08-09
#
#       daily_start  daily_end monthly_start monthly_end      distance
# id
# ...

# %%
station.iloc[:, :7]
# Out:
#                                name country region    wmo  icao  latitude  \
# id
# KSUW0     Superior / South Superior      US     WI   <NA>  KSUW   46.6897
# 72745  Duluth International Airport      US     MN  72745  KDLH   46.8333
# KDYT0             Duluth / East End      US     MN   <NA>  KDYT   46.7219
# KCOQ0                       Cloquet      US     MN   <NA>  KCOQ   46.7011
# KTWM0           Two Harbors / Waldo      US     MN   <NA>  KTWM   47.0491
#
#        longitude
# id
# KSUW0   -92.0947
# 72745   -92.2167
# KDYT0   -92.0434
# KCOQ0   -92.5036
# KTWM0   -91.7452

# %%
stations = stations.nearby(46.179749, -94.223059)
station = stations.fetch(300)

# %%
station.iloc[:, :7]
# Out:
#                                                     name country region  \
# id
# KRYM0            Ray S Miller Aaf / Camp Ripley Junction      US     MN
# KBRD0               Brainerd / Lazy Acre's Trailer Court      US     MN
# KLXL0                             Little Falls / Gregory      US     MN
# KSAZ0                                            Staples      US     MN
# KAIT0         Aitkin / Welshons Company Mobile Home Park      US     MN
# LVKGQ                                 Todd Field Airport      US     MN
# KPWC0                                         Pine River      US     MN
# 72655                     Saint Cloud / St Cloud / Cable      US     MN
# KD390                                        Sauk Centre      US     MN
# KJMR0                                               Mora      US     MN
# KADC0                         Wadena / West Wind Estates      US     MN
# KPNM0               Princeton / Princetown [Misspelling]      US     MN
# ...

# %%
station.to_csv("stations.csv")

# %%
from meteostat import Stations

stations = Stations()
stations = stations.region('US', 'MN')
print('Stations in Ontario:', stations.count())
# Out:
# Stations in Ontario: 102

# %%
df = pd.read_csv("Station_downsample.csv")

# %%
x = [(df["id"].tolist()[i], df["latitude"].tolist()[i],
      df["longitude"].tolist()[i]) for i in range(df.shape[0])]

# %%
x
# Out:
# [('KMIC0', 45.062, -93.3539),
#  ('KFCM0', 44.8275, -93.4586),
#  ('KSTP0', 44.9346, -93.0603),
#  ('72658', 44.8667, -93.05),
#  ('KSGS0', 44.8571, -93.0329),
#  ('KLVN0', 44.6279, -93.2281),
#  ('KFBL0', 44.3275, -93.3107),
#  ('KOWA0', 44.123000000000005, -93.2588),
#  ('KTOB0', 44.018, -92.8315),
#  ('KAEL0', 43.6815, -93.3672),
#  ('72644', 43.9, -92.5),
#  ('KAUM0', 43.6626, -92.9329),
#  ('KONA0', 44.0772, -91.7083),
#  ('KFKA0', 43.6767, -92.1797),
#  ('KULM0', 44.3197, -94.5023),
#  ('KMKT0', 44.2228, -93.9193),
#  ('KJYG0', 43.9863, -94.5579),
#  ('KMWM0', 43.9134, -95.1094),
#  ('KFRM0', 43.6439, -94.4156),
#  ('KMJQ0', 43.65, -94.9865),
#  ('KOTG0', 43.6551, -95.5792),
#  ('KLJF0', 45.1, -94.5),
#  ('KBDH0', 45.117, -95.1293),
#  ('KHCD0', 44.8599, -94.3825),
#  ('KOVL0', 44.7786, -95.0328),
#  ('KMVE0', 44.9691, -95.7103),
#  ('KGDB0', 44.7533, -95.556),
#  ('KDXX0', 44.9864, -96.1778),
#  ('KCNB0', 44.7295, -96.266),
#  ('KMML0', 44.4517, -95.8244),
# ...

# %%
df
# Out:
#     OBJECTID *       District     id  \
# 0            1          Metro  KMIC0
# 1            2          Metro  KFCM0
# 2            3          Metro  KSTP0
# 3            4          Metro  72658
# 4            5          Metro  KSGS0
# 5            6          Metro  KLVN0
# 6            7      Rochester  KFBL0
# 7            8      Rochester  KOWA0
# 8            9  Rochester\r\n  KTOB0
# 9           10      Rochester  KAEL0
# 10          11      Rochester  72644
# 11          12  Rochester\r\n  KAUM0
# 12          13  Rochester\r\n  KONA0
# 13          14      Rochester  KFKA0
# 14          15        Mankato  KULM0
# 15          16        Mankato  KMKT0
# 16          17        Mankato  KJYG0
# 17          18        Mankato  KMWM0
# 18          19        Mankato  KFRM0
# 19          20        Mankato  KMJQ0
# 20          21        Mankato  KOTG0
# 21          22        Willmar  KLJF0
# 22          23        Willmar  KBDH0
# 23          24        Willmar  KHCD0
# ...

# %%
df_new = df[["District", "id", "latitude", "longitude"]]

# %%
df_new["Percipatation"] = None
# Out:
# ...
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_new
# Out:
#          District     id  latitude  longitude Percipatation
# 0           Metro  KMIC0   45.0620   -93.3539          None
# 1           Metro  KFCM0   44.8275   -93.4586          None
# 2           Metro  KSTP0   44.9346   -93.0603          None
# 3           Metro  72658   44.8667   -93.0500          None
# 4           Metro  KSGS0   44.8571   -93.0329          None
# 5           Metro  KLVN0   44.6279   -93.2281          None
# 6       Rochester  KFBL0   44.3275   -93.3107          None
# 7       Rochester  KOWA0   44.1230   -93.2588          None
# 8   Rochester\r\n  KTOB0   44.0180   -92.8315          None
# 9       Rochester  KAEL0   43.6815   -93.3672          None
# 10      Rochester  72644   43.9000   -92.5000          None
# 11  Rochester\r\n  KAUM0   43.6626   -92.9329          None
# 12  Rochester\r\n  KONA0   44.0772   -91.7083          None
# 13      Rochester  KFKA0   43.6767   -92.1797          None
# 14        Mankato  KULM0   44.3197   -94.5023          None
# ...

# %%
for row in range(len(df)):
  df.at[row, 'c1'] = 'data-' + str(df.at[row, 'c1'])
  print(df.at[row, 'c1'], df.at[row, 'c2'])
